# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread('images.jpg')

# %%
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(20,8))
plt.imshow(img_rgb)

# %%
img_hsv=cv2.cvtColor(img_rgb,cv2.COLOR_RGB2HSV)

# %%
# green_lower=np.array([55,150,50])
# green_upper=np.array([65,255,255])

# %%
# sky_blue_lower=np.array([85,150,50])
# sky_blue_upper=np.array([95,255,255])

# %%
# blue_lower=np.array([115,150,50])
# blue_upper=np.array([125,255,255])

# %%
# pink_lower=np.array([145,150,50])
# pink_upper=np.array([155,255,255])

# %%
lower=np.array([0,150,150])# red color 
upper=np.array([25,255,255])# red color

# %%
mask=cv2.inRange(img_hsv,lower,upper)
plt.figure(figsize=(20,8))
plt.imshow(mask)

# %%
res=cv2.bitwise_and(img_rgb,img_rgb,mask=mask)
plt.figure(figsize=(20,8))
plt.imshow(res)
